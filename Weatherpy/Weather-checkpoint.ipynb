# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

from api_keys import weather_api_key

from citipy import citipy

output_data_file = "output_data/cities.csv"

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
coords = []
cities = []

# Create a set of random latitude and longitude combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
coords = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    
    # If the city is unique, then add it to a cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 586

# %%
max_temp = []
humidity = []
cloudiness = []
wind = []
city_lat = []
city_long = []
country = []
date = []
city_name = []

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# %%
print('Beginning Data Retrieval')
print('--------------------------------')

#loop to get information from the cities

i = 0
set_counter = 1

for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        city_lat.append(response['coord']['lat'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        city_long.append(response['coord']['lon'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        print(f'Processing Record {i} of Set {set_counter} | {city}')
        if i == 49:
            i = 0
            set_counter += 1
        else:
            i += 1
    except(KeyError):
        print("City not found. Skipping...")
        
        
        
print('-----------------------------')
print('Data Retrieval Complete')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 0 of Set 1 | saskylakh
# Processing Record 1 of Set 1 | yulara
# Processing Record 2 of Set 1 | qinhuangdao
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | ranong
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | talnakh
# Processing Record 7 of Set 1 | luderitz
# Processing Record 8 of Set 1 | lorengau
# Processing Record 9 of Set 1 | northam
# Processing Record 10 of Set 1 | te anau
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | mecca
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | faanui
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 18 of Set 1 | brae
# Processing Record 19 of Set 1 | mercedes
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | mayo
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | moerai
# City not found. Skipping...
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | nanortalik
# Processing Record 30 of Set 1 | geraldton
# Processing Record 31 of Set 1 | padang
# Processing Record 32 of Set 1 | ostrovnoy
# Processing Record 33 of Set 1 | champerico
# Processing Record 34 of Set 1 | cornedo vicentino
# Processing Record 35 of Set 1 | ancud
# Processing Record 36 of Set 1 | cabo san lucas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 1 | saldanha
# Processing Record 38 of Set 1 | roebourne
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | mana
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | teacapan
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | aykhal
# Processing Record 49 of Set 1 | oulainen
# City not found. Skipping...
# Processing Record 0 of Set 2 | punta arenas
# Processing Record 1 of Set 2 | riyadh
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | lishui
# Processing Record 4 of Set 2 | ashland
# City not found. Skipping...
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | ipira
# Processing Record 7 of Set 2 | naze
# Processing Record 8 of Set 2 | conceicao do araguaia
# Processing Record 9 of Set 2 | clyde river
# City not found. Skipping...
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | cayenne
# Processing Record 12 of Set 2 | ilulissat
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | valdez
# Processing Record 15 of Set 2 | colomi
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | portland
# Processing Record 20 of Set 2 | nelson bay
# Processing Record 21 of Set 2 | kumhari
# Processing Record 22 of Set 2 | mersing
# Processing Record 23 of Set 2 | tautira
# Processing Record 24 of Set 2 | cuiluan
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | cidreira
# Processing Record 27 of Set 2 | anloga
# Processing Record 28 of Set 2 | leshukonskoye
# Processing Record 29 of Set 2 | vardo
# Processing Record 30 of Set 2 | trat
# Processing Record 31 of Set 2 | camacari
# City not found. Skipping...
# Processing Record 32 of Set 2 | kushima
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | souillac
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | dwarka
# Processing Record 38 of Set 2 | kieta
# Processing Record 39 of Set 2 | matamoros
# Processing Record 40 of Set 2 | preobrazheniye
# Processing Record 41 of Set 2 | dargaville
# Processing Record 42 of Set 2 | la serena
# Processing Record 43 of Set 2 | san vicente
# Processing Record 44 of Set 2 | nhulunbuy
# Processing Record 45 of Set 2 | hihya
# Processing Record 46 of Set 2 | longyan
# Processing Record 47 of Set 2 | mangalia
# Processing Record 48 of Set 2 | morro bay
# Processing Record 49 of Set 2 | narsaq
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 0 of Set 3 | rosarito
# Processing Record 1 of Set 3 | kudahuvadhoo
# Processing Record 2 of Set 3 | alofi
# Processing Record 3 of Set 3 | vao
# Processing Record 4 of Set 3 | mongoumba
# City not found. Skipping...
# Processing Record 5 of Set 3 | dembi dolo
# Processing Record 6 of Set 3 | pangkalanbuun
# Processing Record 7 of Set 3 | husavik
# Processing Record 8 of Set 3 | half moon bay
# Processing Record 9 of Set 3 | myitkyina
# Processing Record 10 of Set 3 | mwinilunga
# Processing Record 11 of Set 3 | imeni poliny osipenko
# Processing Record 12 of Set 3 | flinders
# Processing Record 13 of Set 3 | iskateley
# Processing Record 14 of Set 3 | naifaru
# Processing Record 15 of Set 3 | chokurdakh
# City not found. Skipping...
# Processing Record 16 of Set 3 | zhanaozen
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | korla
# City not found. Skipping...
# Processing Record 20 of Set 3 | sfantu gheorghe
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | forbes
# Processing Record 23 of Set 3 | taltal
# City not found. Skipping...
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | altay
# Processing Record 26 of Set 3 | praia da vitoria
# Processing Record 27 of Set 3 | bogorodskoye
# City not found. Skipping...
# Processing Record 28 of Set 3 | fenton
# Processing Record 29 of Set 3 | bluff
# Processing Record 30 of Set 3 | catamarca
# Processing Record 31 of Set 3 | umba
# Processing Record 32 of Set 3 | adrar
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | acapulco
# Processing Record 35 of Set 3 | cassilandia
# Processing Record 36 of Set 3 | camacha
# Processing Record 37 of Set 3 | coolum beach
# City not found. Skipping...
# Processing Record 38 of Set 3 | tandil
# Processing Record 39 of Set 3 | sao joao da barra
# Processing Record 40 of Set 3 | san quintin
# Processing Record 41 of Set 3 | ovre ardal
# Processing Record 42 of Set 3 | la asuncion
# Processing Record 43 of Set 3 | saint george
# Processing Record 44 of Set 3 | hobart
# City not found. Skipping...
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | victor harbor
# City not found. Skipping...
# Processing Record 47 of Set 3 | kakching
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | biak
# City not found. Skipping...
# Processing Record 0 of Set 4 | sola
# Processing Record 1 of Set 4 | prince rupert
# Processing Record 2 of Set 4 | hervey bay
# City not found. Skipping...
# Processing Record 3 of Set 4 | mount gambier
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | nurlat
# City not found. Skipping...
# Processing Record 6 of Set 4 | akonolinga
# Processing Record 7 of Set 4 | puruliya
# Processing Record 8 of Set 4 | la carolina
# Processing Record 9 of Set 4 | maragogi
# Processing Record 10 of Set 4 | barrow
# Processing Record 11 of Set 4 | dhadar
# Processing Record 12 of Set 4 | kasamwa
# Processing Record 13 of Set 4 | opuwo
# Processing Record 14 of Set 4 | tuatapere
# Processing Record 15 of Set 4 | haines junction
# Processing Record 16 of Set 4 | bouake
# City not found. Skipping...
# Processing Record 17 of Set 4 | kroya
# Processing Record 18 of Set 4 | interlaken
# Processing Record 19 of Set 4 | rio gallegos
# Processing Record 20 of Set 4 | codrington
# Processing Record 21 of Set 4 | segezha
# Processing Record 22 of Set 4 | san
# Processing Record 23 of Set 4 | waynesville
# City not found. Skipping...
# Processing Record 24 of Set 4 | necochea
# Processing Record 25 of Set 4 | tabou
# Processing Record 26 of Set 4 | bodden town
# Processing Record 27 of Set 4 | boa vista
# Processing Record 28 of Set 4 | tasiilaq
# Processing Record 29 of Set 4 | lagoa
# Processing Record 30 of Set 4 | saurimo
# Processing Record 31 of Set 4 | mulege
# Processing Record 32 of Set 4 | hobyo
# Processing Record 33 of Set 4 | maarianhamina
# Processing Record 34 of Set 4 | yinchuan
# Processing Record 35 of Set 4 | hereford
# City not found. Skipping...
# Processing Record 36 of Set 4 | yar-sale
# Processing Record 37 of Set 4 | ambilobe
# Processing Record 38 of Set 4 | mora
# Processing Record 39 of Set 4 | quatre cocos
# Processing Record 40 of Set 4 | kashi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 4 | sao gabriel da cachoeira
# City not found. Skipping...
# Processing Record 42 of Set 4 | kem
# Processing Record 43 of Set 4 | ryotsu
# Processing Record 44 of Set 4 | ossora
# Processing Record 45 of Set 4 | lata
# Processing Record 46 of Set 4 | tankara
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | hithadhoo
# Processing Record 49 of Set 4 | ahipara
# Processing Record 0 of Set 5 | komsomolskiy
# Processing Record 1 of Set 5 | micheweni
# Processing Record 2 of Set 5 | longyearbyen
# Processing Record 3 of Set 5 | kahului
# Processing Record 4 of Set 5 | axim
# Processing Record 5 of Set 5 | hamilton
# Processing Record 6 of Set 5 | airai
# Processing Record 7 of Set 5 | almaznyy
# Processing Record 8 of Set 5 | saint-philippe
# Processing Record 9 of Set 5 | jutai
# Processing Record 10 of Set 5 | waddan
# City not found. Skipping...
# Processing Record 11 of Set 5 | mount isa
# Processing Record 12 of Set 5 | salalah
# Processing Record 13 of Set 5 | nemuro
# Processing Record 14 of Set 5 | neiafu
# Processing Record 15 of Set 5 | chuy
# Processing Record 16 of Set 5 | isangel
# Processing Record 17 of Set 5 | general roca
# Processing Record 18 of Set 5 | sisimiut
# Processing Record 19 of Set 5 | erzin
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | finschhafen
# Processing Record 22 of Set 5 | venezuela
# Processing Record 23 of Set 5 | beringovskiy
# Processing Record 24 of Set 5 | comodoro rivadavia
# Processing Record 25 of Set 5 | siero
# Processing Record 26 of Set 5 | dicabisagan
# Processing Record 27 of Set 5 | buta
# Processing Record 28 of Set 5 | new norfolk
# City not found. Skipping...
# Processing Record 29 of Set 5 | gouyave
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | sorland
# Processing Record 32 of Set 5 | dom pedrito
# Processing Record 33 of Set 5 | ridgecrest
# Processing Record 34 of Set 5 | margate
# Processing Record 35 of Set 5 | puerto madero
# Processing Record 36 of Set 5 | sitka
# Processing Record 37 of Set 5 | ust-shonosha
# Processing Record 38 of Set 5 | sobolevo
# Processing Record 39 of Set 5 | vaini
# Processing Record 40 of Set 5 | skjervoy
# Processing Record 41 of Set 5 | jardim
# Processing Record 42 of Set 5 | mancio lima
# Processing Record 43 of Set 5 | dire
# Processing Record 44 of Set 5 | walvis bay
# Processing Record 45 of Set 5 | zhuhai
# Processing Record 46 of Set 5 | kashan
# Processing Record 47 of Set 5 | pisco
# Processing Record 48 of Set 5 | sakhipur
# Processing Record 49 of Set 5 | alice springs
# Processing Record 0 of Set 6 | atambua
# Processing Record 1 of Set 6 | srednekolymsk
# City not found. Skipping...
# Processing Record 2 of Set 6 | mangrol
# Processing Record 3 of Set 6 | tual
# Processing Record 4 of Set 6 | aklavik
# Processing Record 5 of Set 6 | marsh harbour
# Processing Record 6 of Set 6 | fort nelson
# Processing Record 7 of Set 6 | mahalapye
# Processing Record 8 of Set 6 | leningradskiy
# Processing Record 9 of Set 6 | wainwright
# Processing Record 10 of Set 6 | ouesso
# Processing Record 11 of Set 6 | gazojak
# Processing Record 12 of Set 6 | linjiang
# Processing Record 13 of Set 6 | vostok
# Processing Record 14 of Set 6 | pevek
# City not found. Skipping...
# Processing Record 15 of Set 6 | san patricio
# Processing Record 16 of Set 6 | dubbo
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | kolondieba
# City not found. Skipping...
# Processing Record 19 of Set 6 | pacific grove
# Processing Record 20 of Set 6 | nabire
# Processing Record 21 of Set 6 | metro
# Processing Record 22 of Set 6 | nome
# Processing Record 23 of Set 6 | silute
# Processing Record 24 of Set 6 | marzuq
# Processing Record 25 of Set 6 | pinyug
# Processing Record 26 of Set 6 | norman wells
# Processing Record 27 of Set 6 | male
# Processing Record 28 of Set 6 | roma
# Processing Record 29 of Set 6 | kihei
# Processing Record 30 of Set 6 | hecun
# Processing Record 31 of Set 6 | kautokeino
# Processing Record 32 of Set 6 | ballina
# Processing Record 33 of Set 6 | taicheng
# Processing Record 34 of Set 6 | sayyan
# Processing Record 35 of Set 6 | teya
# Processing Record 36 of Set 6 | yabassi
# City not found. Skipping...
# Processing Record 37 of Set 6 | yumen
# Processing Record 38 of Set 6 | butaritari
# Processing Record 39 of Set 6 | kawalu
# Processing Record 40 of Set 6 | waingapu
# Processing Record 41 of Set 6 | thongwa
# Processing Record 42 of Set 6 | erenhot
# City not found. Skipping...
# Processing Record 43 of Set 6 | heihe
# Processing Record 44 of Set 6 | bowen
# Processing Record 45 of Set 6 | iqaluit
# Processing Record 46 of Set 6 | sinnamary
# Processing Record 47 of Set 6 | muros
# Processing Record 48 of Set 6 | vila franca do campo
# Processing Record 49 of Set 6 | rongcheng
# Processing Record 0 of Set 7 | katiola
# Processing Record 1 of Set 7 | brownsville
# Processing Record 2 of Set 7 | asmar
# Processing Record 3 of Set 7 | richards bay
# Processing Record 4 of Set 7 | los llanos de aridane
# Processing Record 5 of Set 7 | rey bouba
# Processing Record 6 of Set 7 | oriximina
# Processing Record 7 of Set 7 | visby
# Processing Record 8 of Set 7 | hirara
# Processing Record 9 of Set 7 | bubaque
# Processing Record 10 of Set 7 | otane
# Processing Record 11 of Set 7 | okha
# Processing Record 12 of Set 7 | jiamusi
# Processing Record 13 of Set 7 | paamiut
# Processing Record 14 of Set 7 | sakaiminato
# Processing Record 15 of Set 7 | cacoal
# Processing Record 16 of Set 7 | ratnagiri
# Processing Record 17 of Set 7 | wodonga
# Processing Record 18 of Set 7 | hami
# Processing Record 19 of Set 7 | bengkulu
# Processing Record 20 of Set 7 | bathsheba
# Processing Record 21 of Set 7 | dongobesh
# Processing Record 22 of Set 7 | ucluelet
# City not found. Skipping...
# Processing Record 23 of Set 7 | barentu
# Processing Record 24 of Set 7 | bontang
# Processing Record 25 of Set 7 | hinton
# City not found. Skipping...
# Processing Record 26 of Set 7 | lukovetskiy
# Processing Record 27 of Set 7 | anchorage
# Processing Record 28 of Set 7 | palmer
# Processing Record 29 of Set 7 | esperance
# Processing Record 30 of Set 7 | taksimo
# Processing Record 31 of Set 7 | san luis
# Processing Record 32 of Set 7 | harper
# Processing Record 33 of Set 7 | hay river
# Processing Record 34 of Set 7 | bandar-e lengeh
# Processing Record 35 of Set 7 | eureka
# Processing Record 36 of Set 7 | daru
# Processing Record 37 of Set 7 | port hardy
# Processing Record 38 of Set 7 | kutulik
# Processing Record 39 of Set 7 | olafsvik
# City not found. Skipping...
# Processing Record 40 of Set 7 | saint-pierre
# Processing Record 41 of Set 7 | dzaoudzi
# Processing Record 42 of Set 7 | porto novo
# Processing Record 43 of Set 7 | grootfontein
# Processing Record 44 of Set 7 | sabang
# Processing Record 45 of Set 7 | kibakwe
# Processing Record 46 of Set 7 | manggar
# Processing Record 47 of Set 7 | amuntai
# Processing Record 48 of Set 7 | kruisfontein
# Processing Record 49 of Set 7 | port lincoln
# Processing Record 0 of Set 8 | zaykovo
# Processing Record 1 of Set 8 | wilmington
# Processing Record 2 of Set 8 | hofn
# Processing Record 3 of Set 8 | wakkanai
# Processing Record 4 of Set 8 | gadsden
# Processing Record 5 of Set 8 | pangnirtung
# Processing Record 6 of Set 8 | pangody
# Processing Record 7 of Set 8 | abnub
# Processing Record 8 of Set 8 | agirish
# Processing Record 9 of Set 8 | zolotkovo
# Processing Record 10 of Set 8 | saint-georges
# Processing Record 11 of Set 8 | abu samrah
# Processing Record 12 of Set 8 | shibetsu
# Processing Record 13 of Set 8 | namatanai
# Processing Record 14 of Set 8 | kavaratti
# Processing Record 15 of Set 8 | yeppoon
# Processing Record 16 of Set 8 | tiksi
# Processing Record 17 of Set 8 | xuddur
# Processing Record 18 of Set 8 | kismayo
# Processing Record 19 of Set 8 | kiama
# Processing Record 20 of Set 8 | colac
# Processing Record 21 of Set 8 | beloha
# Processing Record 22 of Set 8 | waipawa
# Processing Record 23 of Set 8 | manokwari
# Processing Record 24 of Set 8 | pandan
# Processing Record 25 of Set 8 | kisumu
# Processing Record 26 of Set 8 | bognor regis
# Processing Record 27 of Set 8 | mahebourg
# City not found. Skipping...
# Processing Record 28 of Set 8 | waverly
# Processing Record 29 of Set 8 | olinda
# City not found. Skipping...
# Processing Record 30 of Set 8 | kyabram
# Processing Record 31 of Set 8 | saint-augustin
# Processing Record 32 of Set 8 | tiarei
# Processing Record 33 of Set 8 | belyy yar
# Processing Record 34 of Set 8 | dingle
# Processing Record 35 of Set 8 | buraydah
# Processing Record 36 of Set 8 | great yarmouth
# Processing Record 37 of Set 8 | mimoso do sul
# Processing Record 38 of Set 8 | linxia
# Processing Record 39 of Set 8 | havoysund
# Processing Record 40 of Set 8 | kupang
# Processing Record 41 of Set 8 | george
# Processing Record 42 of Set 8 | aracaju
# Processing Record 43 of Set 8 | mackenzie
# Processing Record 44 of Set 8 | oranjemund
# Processing Record 45 of Set 8 | aksay
# Processing Record 46 of Set 8 | sydney
# City not found. Skipping...
# Processing Record 47 of Set 8 | nisia floresta
# Processing Record 48 of Set 8 | shimoda
# Processing Record 49 of Set 8 | nong khai
# Processing Record 0 of Set 9 | sun valley
# Processing Record 1 of Set 9 | gucheng
# Processing Record 2 of Set 9 | tuy hoa
# Processing Record 3 of Set 9 | tezu
# Processing Record 4 of Set 9 | ostersund
# Processing Record 5 of Set 9 | asau
# Processing Record 6 of Set 9 | nishihara
# Processing Record 7 of Set 9 | niceville
# Processing Record 8 of Set 9 | itarema
# Processing Record 9 of Set 9 | seddon
# Processing Record 10 of Set 9 | honningsvag
# Processing Record 11 of Set 9 | coruripe
# Processing Record 12 of Set 9 | killam
# Processing Record 13 of Set 9 | general pico
# Processing Record 14 of Set 9 | college
# Processing Record 15 of Set 9 | whitianga
# City not found. Skipping...
# Processing Record 16 of Set 9 | rawson
# Processing Record 17 of Set 9 | yuci
# Processing Record 18 of Set 9 | grindavik
# Processing Record 19 of Set 9 | taoudenni
# Processing Record 20 of Set 9 | dongsheng
# Processing Record 21 of Set 9 | aleksandrovskoye
# Processing Record 22 of Set 9 | banjar
# Processing Record 23 of Set 9 | presidente epitacio
# Processing Record 24 of Set 9 | shabo
# Processing Record 25 of Set 9 | kavieng
# Processing Record 26 of Set 9 | koutsouras
# Processing Record 27 of Set 9 | silleda
# Processing Record 28 of Set 9 | qui nhon
# Processing Record 29 of Set 9 | kundiawa
# Processing Record 30 of Set 9 | cherskiy
# Processing Record 31 of Set 9 | coquimbo
# Processing Record 32 of Set 9 | koltubanovskiy
# Processing Record 33 of Set 9 | sombrio
# Processing Record 34 of Set 9 | onokhoy
# City not found. Skipping...
# Processing Record 35 of Set 9 | safford
# Processing Record 36 of Set 9 | diffa
# Processing Record 37 of Set 9 | medvezhyegorsk
# Processing Record 38 of Set 9 | tianpeng
# Processing Record 39 of Set 9 | vila velha
# Processing Record 40 of Set 9 | rocha
# Processing Record 41 of Set 9 | wanning
# Processing Record 42 of Set 9 | tsuyama
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 9 | damietta
# Processing Record 44 of Set 9 | lasa
# Processing Record 45 of Set 9 | rio verde de mato grosso
# Processing Record 46 of Set 9 | solihull
# Processing Record 47 of Set 9 | vila
# Processing Record 48 of Set 9 | cadillac
# Processing Record 49 of Set 9 | kolyvan
# Processing Record 0 of Set 10 | moron
# Processing Record 1 of Set 10 | lazaro cardenas
# City not found. Skipping...
# Processing Record 2 of Set 10 | vangaindrano
# Processing Record 3 of Set 10 | kutum
# Processing Record 4 of Set 10 | mahuva
# Processing Record 5 of Set 10 | guiong
# Processing Record 6 of Set 10 | yakovlevo
# Processing Record 7 of Set 10 | phonhong
# Processing Record 8 of Set 10 | tessalit
# Processing Record 9 of Set 10 | fukue
# Processing Record 10 of Set 10 | ulladulla
# Processing Record 11 of Set 10 | uige
# Processing Record 12 of Set 10 | verkhnevilyuysk
# Processing Record 13 of Set 10 | santa fe
# Processing Record 14 of Set 10 | rexburg
# Processing Record 15 of Set 10 | hualmay
# Processing Record 16 of Set 10 | maxixe
# Processing Record 17 of Set 10 | urucara
# Processing Record 18 of Set 10 | siva
# Processing Record 19 of Set 10 | sicuani
# Processing Record 20 of Set 10 | tahta
# Processing Record 21 of Set 10 | honiara
# Processing Record 22 of Set 10 | lavrentiya
# Processing Record 23 of Set 10 | dzhebariki-khaya
# Processing Record 24 of Set 10 | cozumel
# Processing Record 25 of Set 10 | plouzane
# City not found. Skipping...
# Processing Record 26 of Set 10 | ziro
# Processing Record 27 of Set 10 | kvareli
# Processing Record 28 of Set 10 | quelimane
# Processing Record 29 of Set 10 | eydhafushi
# Processing Record 30 of Set 10 | arani
# City not found. Skipping...
# Processing Record 31 of Set 10 | balikpapan
# Processing Record 32 of Set 10 | nara
# Processing Record 33 of Set 10 | pareora
# Processing Record 34 of Set 10 | pattaya
# Processing Record 35 of Set 10 | waraseoni
# Processing Record 36 of Set 10 | kotido
# Processing Record 37 of Set 10 | ust-ishim
# Processing Record 38 of Set 10 | la ronge
# Processing Record 39 of Set 10 | namibe
# Processing Record 40 of Set 10 | oruro
# Processing Record 41 of Set 10 | mabaruma
# Processing Record 42 of Set 10 | shihezi
# Processing Record 43 of Set 10 | pietarsaari
# Processing Record 44 of Set 10 | north bend
# Processing Record 45 of Set 10 | inirida
# City not found. Skipping...
# Processing Record 46 of Set 10 | kaitangata
# City not found. Skipping...
# Processing Record 47 of Set 10 | partizanskoye
# Processing Record 48 of Set 10 | nizwa
# Processing Record 49 of Set 10 | ganzhou
# Processing Record 0 of Set 11 | zhigansk
# Processing Record 1 of Set 11 | xam nua
# Processing Record 2 of Set 11 | mayumba
# Processing Record 3 of Set 11 | lebanon
# Processing Record 4 of Set 11 | mastic beach
# Processing Record 5 of Set 11 | yerbogachen
# Processing Record 6 of Set 11 | havelock
# Processing Record 7 of Set 11 | guanica
# Processing Record 8 of Set 11 | touros
# City not found. Skipping...
# Processing Record 9 of Set 11 | pamplona
# Processing Record 10 of Set 11 | yuanping
# Processing Record 11 of Set 11 | chardara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 11 | kamenka
# Processing Record 13 of Set 11 | marang
# Processing Record 14 of Set 11 | qaqortoq
# Processing Record 15 of Set 11 | san cristobal
# Processing Record 16 of Set 11 | soledar
# Processing Record 17 of Set 11 | itupiranga
# Processing Record 18 of Set 11 | schattdorf
# Processing Record 19 of Set 11 | coos bay
# Processing Record 20 of Set 11 | soure
# Processing Record 21 of Set 11 | cabedelo
# Processing Record 22 of Set 11 | taree
# Processing Record 23 of Set 11 | qiongshan
# Processing Record 24 of Set 11 | shasta lake
# Processing Record 25 of Set 11 | halifax
# Processing Record 26 of Set 11 | ginir
# Processing Record 27 of Set 11 | pontianak
# Processing Record 28 of Set 11 | villazon
# Processing Record 29 of Set 11 | nouadhibou
# City not found. Skipping...
# Processing Record 30 of Set 11 | stargard szczecinski
# Processing Record 31 of Set 11 | biskamzha
# Processing Record 32 of Set 11 | zapolyarnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# make a dataframe from the information

weather_df = pd.DataFrame({
    'City' : city_name,
    'Country' : country,
    'Latitude' : city_lat,
    'Longitude' : city_long,
    'Max Temperature' : max_temp,
    'Humidity' : humidity,
    'Wind Speed' : wind,
    'Cloudiness' : cloudiness,
    'Date' : date
})

# %%
# remove any cities with humidity greater than 100

weather_df = weather_df[weather_df['Humidity'] <= 100]
weather_df.head()
# Out:
#           City Country  Latitude  Longitude  Max Temperature  Humidity  \
# 0    Saskylakh      RU   71.9167   114.0833            -4.76        89
# 1       Yulara      AU  -25.2406   130.9889            64.40        48
# 2  Qinhuangdao      CN   39.9317   119.5883            48.07        62
# 3   Nikolskoye      RU   59.7035    30.7861            37.00        86
# 4       Ranong      TH    9.9658    98.6348            78.30        85
#
#    Wind Speed  Cloudiness        Date
# 0       10.40          23  1618080067
# 1       11.50           0  1618080093
# 2        6.44          71  1618080302
# 3        2.24          40  1618080054
# 4        4.38          58  1618080492

# %% [markdown]
# # Scatterplots

# %%
# temp v lat
x_values = weather_df['Latitude']

y_values = weather_df['Max Temperature']

plt.scatter(x_values, y_values, color = 'orangered')
plt.xlabel('Latitude')
plt.ylabel('Maximum Tempurature (F)')
plt.title('Temperature (F) vs. Latitude')
plt.tight_layout
plt.savefig('world_temp_v_lat')
plt.show()
print('This is a comparison of maximum temperature to latitude of each city in the dataframe.')
print('As the city gets closer to the equator (latitude is closer to zero), the temperatures to rise')
# Out:
# This is a comparison of maximum temperature to latitude of each city in the dataframe.
# As the city gets closer to the equator (latitude is closer to zero), the temperatures to rise

# %%
# hum v lat

y_values = weather_df['Humidity']

plt.scatter(x_values, y_values, color = 'springgreen')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Humidity (%) vs. Latitude')
plt.tight_layout
plt.savefig('world_hum_v_lat')
plt.show()

print('This is a comparison of average humidity to latitude of each city in the dataframe.')
print('The cities with lower humidity are closer to the equator than some of the cities with high humidity.')
# Out:
# This is a comparison of average humidity to latitude of each city in the dataframe.
# The cities with lower humidity are closer to the equator than some of the cities with high humidity.

# %%
# cloudiness

y_values = weather_df['Cloudiness']

plt.scatter(x_values, y_values, color = 'skyblue')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Cloudiness (%) vs. Latitude')
plt.tight_layout
plt.savefig('world_cloud_v_lat')
plt.show()

print('This is a comparison of average cloudiness as a percent to latitude of each city in the dataframe.')
print('There seems to be little correlation between the two.')
# Out:
# This is a comparison of average cloudiness as a percent to latitude of each city in the dataframe.
# There seems to be little correlation between the two.

# %%
# wind speed

y_values = weather_df['Wind Speed']

plt.scatter(x_values, y_values, color = 'violet')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Wind Speed (mph) vs. Latitude')
plt.tight_layout
plt.savefig('world_wind_v_lat')
plt.show()

print('This is a comparison of average wind speed to latitude of each city in the dataframe.')
print('There seems to be little correlation between the two.')
# Out:
# This is a comparison of average wind speed to latitude of each city in the dataframe.
# There seems to be little correlation between the two.

# %%
# separate dataframe by hemispheres

north_df = weather_df[weather_df['Latitude'] >= 0]
south_df = weather_df[weather_df['Latitude'] < 0]

# %% [markdown]
# # Northern Hemisphere Regression

# %%
# temp

x_values = north_df['Latitude']

y_values = north_df['Max Temperature']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = slope * x_values + intercept

r = round(rvalue, 2)

plt.plot(x_values, regress_values)
plt.scatter(x_values, y_values, color = 'orangered')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.title('Temperature v Latitude in Northern Hemisphere')
plt.tight_layout
plt.savefig('north_temp_v_lat')
plt.show()

print(f'The correlation is: {r}.')
print('This tells us there is a strong correlation between maximum temperature and distance from the equator')
print('in the Northern hemisphere.')
print('As we move north away from the equator, maximum temperature decreases.')
# Out:
# The correlation is: -0.86.
# This tells us there is a strong correlation between maximum temperature and distance from the equator
# in the Northern hemisphere.
# As we move north away from the equator, maximum temperature decreases.

# %%
# humidity

y_values = north_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = slope * x_values + intercept

r = round(rvalue, 2)

plt.plot(x_values, regress_values)

plt.scatter(x_values, y_values, color = 'springgreen')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Humidity v Latitude in Northern Hemisphere')
plt.tight_layout
plt.savefig('north_hum_v_lat')
plt.show()

print(f"The correlation is: {r}.")
print('This tells us there is little relationship between humidity and distance from the equator')
print('in the Northern hemisphere.')
# Out:
# The correlation is: 0.23.
# This tells us there is little relationship between humidity and distance from the equator
# in the Northern hemisphere.

# %%
# cloudiness

y_values = north_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = slope * x_values + intercept

r = round(rvalue, 2)

plt.plot(x_values, regress_values)

plt.scatter(x_values, y_values, color = 'skyblue')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness v Latitude in Northern Hemisphere')
plt.tight_layout
plt.savefig('north_cloud_v_lat')
plt.show()

print(f'The correlation is: {r}.')
print('This tells us there is little correlation between cloudiness and distance from the equator')
print('in the Northern hemisphere.')
# Out:
# The correlation is: 0.15.
# This tells us there is little correlation between cloudiness and distance from the equator
# in the Northern hemisphere.

# %%
# wind speed

y_values = north_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = slope * x_values + intercept

r = round(rvalue, 2)

plt.plot(x_values, regress_values)

plt.scatter(x_values, y_values, color = 'violet')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.title('Wind Speed (MPH) v Latitude in Northern Hemisphere')
plt.tight_layout
plt.savefig('north_wind_v_lat')
plt.show()

print(f'The correlation is: {r}')
print('This tells us there is little correlation between wind speed and distance from the equator')
print('in the Northern hemisphere.')
# Out:
# The correlation is: 0.09
# This tells us there is little correlation between wind speed and distance from the equator
# in the Northern hemisphere.

# %% [markdown]
# # Southern Hemisphere Regression

# %%
# temp

x_values = south_df['Latitude']

y_values = south_df['Max Temperature']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = slope * x_values + intercept

r = round(rvalue, 2)

plt.plot(x_values, regress_values)

plt.scatter(x_values, y_values, color = 'orangered')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.title('Temperature v Latitude in Southern Hemisphere')
plt.tight_layout
plt.savefig('south_temp_v_lat')
plt.show()

print(f'The correlation is: {r}.')
print('This tells us there is a moderate correlation between maximum temperature and distance from the equator')
print('in the Southern hemisphere')
print('The farther we move from the equator, the lower the maximum temperature.')
# Out:
# The correlation is: 0.64.
# This tells us there is a moderate correlation between maximum temperature and distance from the equator
# in the Southern hemisphere
# The farther we move from the equator, the lower the maximum temperature.

# %%
# humidity

y_values = south_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = slope * x_values + intercept

r = round(rvalue, 2)

plt.plot(x_values, regress_values)

plt.scatter(x_values, y_values, color = 'springgreen')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Humidity v Latitude in Southern Hemisphere')
plt.tight_layout
plt.savefig('south_hum_v_lat')
plt.show()

print(f'The correlation is {r}.')
print('This tells us that there is little correlation between humidity and distance from the equator ')
print('in the Southern hemisphere.')
# Out:
# The correlation is 0.16.
# This tells us that there is little correlation between humidity and distance from the equator
# in the Southern hemisphere.

# %%
# cloudiness

y_values = south_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = slope * x_values + intercept

r = round(rvalue, 2)

plt.plot(x_values, regress_values)

plt.scatter(x_values, y_values, color = 'skyblue')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness v Latitude in Southhern Hemisphere')
plt.tight_layout
plt.savefig('south_cloud_v_lat')
plt.show()

print(f'The correlation is: {r}')
print('There is a weak correlation between cloudiness and distance from the equator')
print('in the Southern hemisphere.')
print('As we move closer to the equator, cloudiness may increase.')
# Out:
# The correlation is: 0.26
# There is a weak correlation between cloudiness and distance from the equator
# in the Southern hemisphere.
# As we move closer to the equator, cloudiness may increase.

# %%
# wind speed

y_values = south_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = slope * x_values + intercept

r = round(rvalue, 2)

plt.plot(x_values, regress_values)

plt.scatter(x_values, y_values, color = 'violet')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.title('Wind Speed (MPH) v Latitude in Southern Hemisphere')
plt.tight_layout
plt.savefig('south_wind_v_lat')
plt.show()

print(f'The correlation is: {r}')
print('There is very little correlation between wind speed and distance from the equator')
print('in the Southern hemisphere.')
# Out:
# The correlation is: -0.24
# There is very little correlation between wind speed and distance from the equator
# in the Southern hemisphere.

# %%
weather_df.to_csv(output_data_file, index = False)
